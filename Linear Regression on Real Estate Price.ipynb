# %%
#importing required libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#import csv file
price=pd.read_csv("Real estate.csv")

# %%
price
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
price.describe()
# Out:
#                No  X1 transaction date  X2 house age  \
# count  414.000000           414.000000    414.000000
# mean   207.500000          2013.148971     17.712560
# std    119.655756             0.281967     11.392485
# min      1.000000          2012.667000      0.000000
# 25%    104.250000          2012.917000      9.025000
# 50%    207.500000          2013.167000     16.100000
# 75%    310.750000          2013.417000     28.150000
# max    414.000000          2013.583000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
# ...

# %%
price.isnull().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
price=price.astype({"X4 number of convenience stores":'int'})
display(price)
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
#Basic information of dataset
price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int32
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int32(1), int64(1)
# memory usage: 24.4 KB

# %%
price.isna().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
cor=price.corr()

# %%
cor.style.background_gradient()
# Out:
# <style type="text/css">
# #T_5b3f2_row0_col0, #T_5b3f2_row1_col1, #T_5b3f2_row2_col2, #T_5b3f2_row3_col3, #T_5b3f2_row4_col4, #T_5b3f2_row5_col5, #T_5b3f2_row6_col6, #T_5b3f2_row7_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_5b3f2_row0_col1, #T_5b3f2_row1_col0, #T_5b3f2_row3_col4, #T_5b3f2_row3_col5, #T_5b3f2_row3_col6, #T_5b3f2_row3_col7, #T_5b3f2_row6_col3, #T_5b3f2_row7_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_5b3f2_row0_col2 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_5b3f2_row0_col3, #T_5b3f2_row0_col6 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_5b3f2_row0_col4 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_5b3f2_row0_col5 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_5b3f2_row0_col7 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_5b3f2_row1_col2 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_5b3f2_row1_col3 {
# ...

# %%
x=price.iloc[:,0:6]

# %%
y=price['Y house price of unit area']

# %%
#Training
from sklearn.model_selection import train_test_split

# %%
#Model Building
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=108)

# %%
x_train
# Out:
#       No  X1 transaction date  X2 house age  \
# 35    36             2013.500          13.9
# 276  277             2013.000          19.1
# 42    43             2013.417          36.1
# 87    88             2013.583          16.9
# 110  111             2013.083           8.1
# ..   ...                  ...           ...
# 342  343             2012.667           5.7
# 366  367             2012.750          14.2
# 145  146             2012.917           2.1
# 279  280             2013.417           2.6
# 99   100             2013.417           6.4
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 35                               4079.41800                                0
# 276                               461.10160                                5
# 42                                519.46170                                5
# 87                               4066.58700                                0
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#Data Prediction
pred=model.predict(x_test)
print(pred)
# Out:
# [12.70599143 12.33316922 44.7138516  33.93964212 43.17765525 46.86852919
#  45.77078916 27.68032504  8.74687971 31.04731893 44.61239882 31.13355823
#  31.33847582 45.76555618 52.872663   40.74418544 43.56486514 45.45629547
#  46.62506782 45.02415205 46.68577403 36.72274092 12.05280655 33.62686974
#  11.81322214 11.53627711 47.07890127 51.65839391 44.59421381 40.66969466
#  47.485946   33.95579587 21.52425371 26.16159906 44.88282702 39.34750044
#  45.38841373 51.41439252 29.42867307 31.25018596 40.87866812 49.28957798
#  39.42163582 20.86269361 45.30405292 45.70067722 10.52997206 14.3536451
#  48.66452747 12.39591023 51.44019219 30.97618918 54.33601055 40.01337594
#  43.22526627 41.25326859 41.8812498  45.21890989 26.84484656 46.20173657
#  36.35569709 29.03303679 15.59440525 49.57270621 14.92227873 39.08850918
#  29.93065364 43.80932243 47.65457382 31.39959738 43.9961833  32.23697265
#  37.69239173 39.07414226 14.37664046 43.57103462  8.45236163 38.09190747
# ...

# %%
#Calculate R square score
from sklearn.metrics import r2_score
r=r2_score(y_test,pred)
print("Value:",r*100)
# Out:
# Value: 69.77740172727513

# %%
sns.regplot(data=price,x=y_test,y=pred,color='green')
# Out:
# <AxesSubplot:xlabel='Y house price of unit area'>

# %%
print(model.coef_)
# Out:
# [ 2.80431135e-04  5.96380548e+00 -2.42510783e-01 -4.36322157e-03
#   1.13757862e+00  2.46287930e+02]

# %%
print(model.intercept_)
# Out:
# -18113.448834281015
